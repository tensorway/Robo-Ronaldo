# %%
import math
import time
import numpy as np
from robocup import field
from robocup import vision
from robocup import switches as s
from robocup import movement as mov
from robocup import commands as comm
from robocup import localization as loc
#from filterpy.kalman import KalmanFilter
from multiprocessing import Process, Value
#from filterpy.common import Q_discrete_white_noise


robot_angle = 225

# %%
xnum = Value('d', 0.0)
ynum = Value('d', 0.0)
anglenum = Value('d', 0.0)
distnum = Value('d', 0.0)
sizenum = Value('d', 0.0)
recnum = Value('d', 0.0)
erasenum = Value('d', 0.0)
#vision.detect_the_ball(anglenum, distnum, sizenum, recnum, True)
p1 = Process(target=loc.localize, args=(robot_angle, xnum, ynum, False))
p2 = Process(target=vision.detect_the_ball, args=(anglenum, distnum, sizenum, recnum, erasenum, False))
p1.start()
p2.start()
# Out:
# 640x480
# 640x480
# Too many measurments in the input buffer: 616/500. Clearing buffer...
# Too many measurments in the input buffer: 503/500. Clearing buffer...
# Too many measurments in the input buffer: 666/500. Clearing buffer...
# Too many measurments in the input buffer: 539/500. Clearing buffer...
# Too many measurments in the input buffer: 657/500. Clearing buffer...
# Too many measurments in the input buffer: 700/500. Clearing buffer...
# Too many measurments in the input buffer: 612/500. Clearing buffer...
# Too many measurments in the input buffer: 666/500. Clearing buffer...
# Too many measurments in the input buffer: 712/500. Clearing buffer...
# Too many measurments in the input buffer: 603/500. Clearing buffer...
# Too many measurments in the input buffer: 646/500. Clearing buffer...
# Too many measurments in the input buffer: 505/500. Clearing buffer...
# Too many measurments in the input buffer: 543/500. Clearing buffer...
# Too many measurments in the input buffer: 549/500. Clearing buffer...
# Too many measurments in the input buffer: 612/500. Clearing buffer...
# Too many measurments in the input buffer: 559/500. Clearing buffer...
# Too many measurments in the input buffer: 796/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 609/500. Clearing buffer...
# Too many measurments in the input buffer: 631/500. Clearing buffer...
# Too many measurments in the input buffer: 615/500. Clearing buffer...
# Too many measurments in the input buffer: 676/500. Clearing buffer...
# Too many measurments in the input buffer: 553/500. Clearing buffer...
# Too many measurments in the input buffer: 757/500. Clearing buffer...
# Too many measurments in the input buffer: 633/500. Clearing buffer...
# Too many measurments in the input buffer: 713/500. Clearing buffer...
# Too many measurments in the input buffer: 623/500. Clearing buffer...
# Too many measurments in the input buffer: 692/500. Clearing buffer...
# Too many measurments in the input buffer: 528/500. Clearing buffer...
# Too many measurments in the input buffer: 575/500. Clearing buffer...
# Too many measurments in the input buffer: 639/500. Clearing buffer...
# Too many measurments in the input buffer: 505/500. Clearing buffer...
# Too many measurments in the input buffer: 567/500. Clearing buffer...
# Too many measurments in the input buffer: 612/500. Clearing buffer...
# Too many measurments in the input buffer: 674/500. Clearing buffer...
# Too many measurments in the input buffer: 636/500. Clearing buffer...
# Too many measurments in the input buffer: 773/500. Clearing buffer...
# Too many measurments in the input buffer: 645/500. Clearing buffer...
# Too many measurments in the input buffer: 517/500. Clearing buffer...
# Too many measurments in the input buffer: 529/500. Clearing buffer...
# Too many measurments in the input buffer: 735/500. Clearing buffer...
# Too many measurments in the input buffer: 562/500. Clearing buffer...
# Too many measurments in the input buffer: 706/500. Clearing buffer...
# Too many measurments in the input buffer: 664/500. Clearing buffer...
# Too many measurments in the input buffer: 747/500. Clearing buffer...
# Too many measurments in the input buffer: 708/500. Clearing buffer...
# Too many measurments in the input buffer: 627/500. Clearing buffer...
# Too many measurments in the input buffer: 745/500. Clearing buffer...
# Too many measurments in the input buffer: 616/500. Clearing buffer...
# Too many measurments in the input buffer: 805/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 654/500. Clearing buffer...
# Too many measurments in the input buffer: 526/500. Clearing buffer...
# Too many measurments in the input buffer: 736/500. Clearing buffer...
# Too many measurments in the input buffer: 814/500. Clearing buffer...
# Too many measurments in the input buffer: 518/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 515/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 639/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 622/500. Clearing buffer...
# Too many measurments in the input buffer: 540/500. Clearing buffer...
# Too many measurments in the input buffer: 737/500. Clearing buffer...
# Too many measurments in the input buffer: 560/500. Clearing buffer...
# Too many measurments in the input buffer: 630/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 500/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 659/500. Clearing buffer...
# Too many measurments in the input buffer: 522/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 514/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 655/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 625/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 568/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 573/500. Clearing buffer...
# Too many measurments in the input buffer: 717/500. Clearing buffer...
# Too many measurments in the input buffer: 626/500. Clearing buffer...
# Too many measurments in the input buffer: 650/500. Clearing buffer...
# Too many measurments in the input buffer: 819/500. Clearing buffer...
# Too many measurments in the input buffer: 710/500. Clearing buffer...
# Too many measurments in the input buffer: 770/500. Clearing buffer...
# Too many measurments in the input buffer: 684/500. Clearing buffer...
# Too many measurments in the input buffer: 672/500. Clearing buffer...
# Too many measurments in the input buffer: 706/500. Clearing buffer...
# Too many measurments in the input buffer: 541/500. Clearing buffer...
# Too many measurments in the input buffer: 640/500. Clearing buffer...
# Too many measurments in the input buffer: 564/500. Clearing buffer...

# %%
erasenum.value = 1

# %%
erasenum.value = 0

# %%
recnum.value = 1

# %%
recnum.value = 0

# %%
while s.state(0):
    a = 0
comm.set_orientation()
while not s.state(0):
    a = 0
comm.start()
x = field.x / 2 + 0.01
y = field.y / 2 + 0.012
seeball = 0
robot_speed = 0.1
goalie = False
ba = 0

while True:
    xc = xnum.value
    yc = ynum.value
    angle = anglenum.value
    ball_size = sizenum.value
    dist = distnum.value   
    
    seeball += 1 if ball_size > 200 else -1 
    if seeball > 10:
        seeball = 10
    if seeball < -1:
        seeball = -1
    if (xc != -1):
        x = xc
    if (yc != -1): 
        y = yc
    """
    if seeball > 2:
        ba = mov.robot_angle_to_catch_ball(angle, x, y)
        _, ba = mov.flatten_angle(upper_dist=400, x=x, y=y, ant=ba, speed=robot_speed)
        robot_speed, angle_out = mov.adaptive_speed_line(max_speed=0.4 , min_speed=0, upper_dist=800, x=x, y=y, ant=(ba)%360)
        
        min_speed = robot_speed
        if angle_out is None:
            comm.set_moving_angle(ba, min_speed)
        else:
            comm.set_moving_angle(angle_out, robot_speed)
    else:
        mov.move_to(x, y, field.x/2, field.y/2)"""
     
    print(x, y, robot_speed, angle, ba, seeball,  "    d   ", end = '\r')
    time.sleep(0.05)
    s.check_pause()
    if not s.state(3):
        break
# Out:
# 332.08676735820535 1275.9647048015713 0.1 46.28732894152503 0 10     d      .02007885425544 0 10     d   0.1 89.2559407971113 0 10     d   215.9435048015708 0.1 24.413331705025115 0 10     d    43.72696997994328 0 10     d

# %%
import cv2

cv2.destroyAllWindows()

# %%
dt = 0.005
kf = KalmanFilter (dim_x=4, dim_z=2)
f.x = np.array([[field.x/2],
                [field.y/2],
                [0.], 
                [0.]])   
    
f.F = np.array([[1., 0., dt, 0.],
                [0., 1., 0., dt],
                [0., 0., 1., 0.],
                [0., 0., 0., 1.]])
    
f.H = np.array([[1., 0., 0., 0.],
                [0., 1., 0., 0.]])
    
f.P *= 1000.
R = np.array([[50., 50.]])
R_nox = np.array([[50000., 50.]])
R_noy = np.array([[50000., 50.]])
R_noxy = np.array([[50000., 50000.]])
f.R = R
f.Q = Q_discrete_white_noise(dim=4, dt=dt, var=0.13)
last_filter_call = time.time()
d_filter_call = 0.005
xf = field.x/2
yf = field.y/2
def filter_loc(was_measurment_updated, xm, ym):
    if was_measurment_updated:
        f.predict()
        f.update(z)
    elif time.time() - last_filter_call > d_filter_call:
        f.predict()
        
    print(f.x) 
    return f.x[0], f.x[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b73d08fd111b> in <module>()
#       1 dt = 0.005
# ----> 2 kf = KalmanFilter (dim_x=4, dim_z=2)
#       3 f.x = np.array([[field.x/2],
#       4                 [field.y/2],
#       5                 [0.],
#
# NameError: name 'KalmanFilter' is not defined

# %%
20*(0>0)
# Out:
# 0

# %%
from robocup import movement as mov
lines = [
    [260, 260, 570, 260],
    [570, 260, 570, 410],
    [570, 410, 660, 520],
    [660, 520, 1160, 520],
    [1160, 520, 1250, 410],
    [1250, 410, 1250, 260],
    [1250, 260, 1560, 260],
    [1560, 260, 1560, 2170],
    [1560, 2170, 1250, 2170],
    [1250, 2170, 1250, 2020],
    [1250, 2020, 1160, 1910],
    [1160, 1910, 660, 1910],
    [660, 1910, 570, 2020],
    [570, 2020, 570, 2170],
    [570, 2170, 260, 2170],
    [260, 2170, 260, 260]
]

# %%
help(mov)
# Out:
# Help on module robocup.movement in robocup:
#
# NAME
#     robocup.movement
#
# FUNCTIONS
#     adaptive_speed_ball(angle_to_go, ball_dist, speed, ball_close_speed)
#
#     adaptive_speed_line(max_speed, min_speed, upper_dist, x, y, ant)
#
#     adaptive_speed_rect(max_speed, min_speed, ball_close_speed, upper_dist, lower_dist, x, y, ant, ball_dist)
#
#     flatten_angle(upper_dist, x, y, ant)
#
#     line_dists(x1, y1)
#
#     move_to(x0, y0, x, y)
#
#     robot_angle_to_catch_ball(ball_angle, x, y)
#
# DATA
#     lines = [[260, 260, 570, 260], [570, 260, 570, 410], [570, 410, 660, 5...
#
# FILE
#     /home/pi/Desktop/24.11.2019. - 21h/jupyter/robocup/movement.py

# %%
mov.flatten_angle(300, 540, 770, 300, 1)
# Out:
# (-8.752538256722763, 0.6259580211832472)
